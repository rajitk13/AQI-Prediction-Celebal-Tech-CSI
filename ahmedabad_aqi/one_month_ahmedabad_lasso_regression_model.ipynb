# %% [markdown]
# <a href="https://colab.research.google.com/github/rajitk13/csi-team-3-project/blob/main/one_month_ahmedabad_lasso_regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/celebal internship/air quality index/ahmedabad_aqi/one_month_ahmedabad.csv')
df.head()
# Out:
#    aqi     co       datetime   no2    o3  pm10   pm25    so2  \
# 0   59  164.0  2023-07-03:18  22.0  36.0  26.0  16.00  103.0
# 1   63  168.7  2023-07-03:17  21.3  44.3  28.7  18.00   78.0
# 2   67  173.3  2023-07-03:16  20.7  52.7  31.3  20.00   53.0
# 3   72  178.0  2023-07-03:15  20.0  61.0  34.0  22.00   28.0
# 4   72  151.0  2023-07-03:14  14.3  74.0  34.3  22.33   22.3
#
#        timestamp_local        timestamp_utc          ts
# 0  2023-07-03T23:30:00  2023-07-03T18:00:00  1688407200
# 1  2023-07-03T22:30:00  2023-07-03T17:00:00  1688403600
# 2  2023-07-03T21:30:00  2023-07-03T16:00:00  1688400000
# 3  2023-07-03T20:30:00  2023-07-03T15:00:00  1688396400
# 4  2023-07-03T19:30:00  2023-07-03T14:00:00  1688392800

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   aqi              721 non-null    int64
#  1   co               721 non-null    float64
#  2   datetime         721 non-null    object
#  3   no2              721 non-null    float64
#  4   o3               721 non-null    float64
#  5   pm10             721 non-null    float64
#  6   pm25             721 non-null    float64
#  7   so2              721 non-null    float64
#  8   timestamp_local  721 non-null    object
#  9   timestamp_utc    721 non-null    object
#  10  ts               721 non-null    int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 62.1+ KB

# %%
y=df.iloc[:,0] ## dependent features
y
# Out:
# 0      59
# 1      63
# 2      67
# 3      72
# 4      72
#        ..
# 716    47
# 717    46
# 718    51
# 719    54
# 720    56
# Name: aqi, Length: 721, dtype: int64

# %%
df.columns
# Out:
# Index(['aqi', 'co', 'datetime', 'no2', 'o3', 'pm10', 'pm25', 'so2',
#        'timestamp_local', 'timestamp_utc', 'ts'],
#       dtype='object')

# %%
X=df[['co', 'datetime', 'no2', 'o3', 'pm10', 'pm25', 'so2',
       'timestamp_local', 'timestamp_utc', 'ts']] ## independent features

# %%
X
# Out:
#         co       datetime   no2    o3  pm10   pm25    so2  \
# 0    164.0  2023-07-03:18  22.0  36.0  26.0  16.00  103.0
# 1    168.7  2023-07-03:17  21.3  44.3  28.7  18.00   78.0
# 2    173.3  2023-07-03:16  20.7  52.7  31.3  20.00   53.0
# 3    178.0  2023-07-03:15  20.0  61.0  34.0  22.00   28.0
# 4    151.0  2023-07-03:14  14.3  74.0  34.3  22.33   22.3
# ..     ...            ...   ...   ...   ...    ...    ...
# 716  104.3  2023-06-03:22  18.0  16.3  18.3  11.33   79.0
# 717  112.0  2023-06-03:21  22.0  14.0  18.0  11.00   90.0
# 718  124.7  2023-06-03:20  24.7  17.3  20.0  12.33   99.0
# 719  137.3  2023-06-03:19  27.3  20.7  22.0  13.67  108.0
# 720  150.0  2023-06-03:18  30.0  24.0  24.0  15.00  117.0
#
#          timestamp_local        timestamp_utc          ts
# 0    2023-07-03T23:30:00  2023-07-03T18:00:00  1688407200
# 1    2023-07-03T22:30:00  2023-07-03T17:00:00  1688403600
# 2    2023-07-03T21:30:00  2023-07-03T16:00:00  1688400000
# 3    2023-07-03T20:30:00  2023-07-03T15:00:00  1688396400
# 4    2023-07-03T19:30:00  2023-07-03T14:00:00  1688392800
# ..                   ...                  ...         ...
# 716  2023-06-04T03:30:00  2023-06-03T22:00:00  1685829600
# 717  2023-06-04T02:30:00  2023-06-03T21:00:00  1685826000
# 718  2023-06-04T01:30:00  2023-06-03T20:00:00  1685822400
# 719  2023-06-04T00:30:00  2023-06-03T19:00:00  1685818800
# 720  2023-06-03T23:30:00  2023-06-03T18:00:00  1685815200
#
# [721 rows x 10 columns]

# %%
X.isnull()
# Out:
#         co  datetime    no2     o3   pm10   pm25    so2  timestamp_local  \
# 0    False     False  False  False  False  False  False            False
# 1    False     False  False  False  False  False  False            False
# 2    False     False  False  False  False  False  False            False
# 3    False     False  False  False  False  False  False            False
# 4    False     False  False  False  False  False  False            False
# ..     ...       ...    ...    ...    ...    ...    ...              ...
# 716  False     False  False  False  False  False  False            False
# 717  False     False  False  False  False  False  False            False
# 718  False     False  False  False  False  False  False            False
# 719  False     False  False  False  False  False  False            False
# 720  False     False  False  False  False  False  False            False
#
#      timestamp_utc     ts
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ..             ...    ...
# 716          False  False
# 717          False  False
# 718          False  False
# 719          False  False
# 720          False  False
#
# [721 rows x 10 columns]

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#            aqi        co       no2        o3      pm10      pm25       so2  \
# aqi   1.000000 -0.017322  0.088953  0.487438  0.912383  0.986413  0.064518
# co   -0.017322  1.000000  0.533528 -0.343914 -0.195016  0.007888  0.105797
# no2   0.088953  0.533528  1.000000 -0.536198 -0.135707  0.087328  0.563342
# o3    0.487438 -0.343914 -0.536198  1.000000  0.602362  0.494090 -0.209547
# pm10  0.912383 -0.195016 -0.135707  0.602362  1.000000  0.924172  0.037139
# pm25  0.986413  0.007888  0.087328  0.494090  0.924172  1.000000  0.051393
# so2   0.064518  0.105797  0.563342 -0.209547  0.037139  0.051393  1.000000
# ts   -0.006297  0.297168  0.120948 -0.310887 -0.115965  0.007286 -0.363118
#
#             ts
# aqi  -0.006297
# co    0.297168
# no2   0.120948
# o3   -0.310887
# pm10 -0.115965
# pm25  0.007286
# so2  -0.363118
# ts    1.000000

# %%
import seaborn as sns
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="BuPu")
# Out:
# <ipython-input-15-eb5df078eb6c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
corrmat.index
# Out:
# Index(['aqi', 'co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'ts'], dtype='object')

# %%
X = X.drop(['datetime'],axis=1)
X = X.drop(['timestamp_local'],axis=1)
X = X.drop(['timestamp_utc'],axis=1)
X.head()
# Out:
#       co   no2    o3  pm10   pm25    so2          ts
# 0  164.0  22.0  36.0  26.0  16.00  103.0  1688407200
# 1  168.7  21.3  44.3  28.7  18.00   78.0  1688403600
# 2  173.3  20.7  52.7  31.3  20.00   53.0  1688400000
# 3  178.0  20.0  61.0  34.0  22.00   28.0  1688396400
# 4  151.0  14.3  74.0  34.3  22.33   22.3  1688392800

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
X.head()

print(model.feature_importances_)

feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()
# Out:
# [0.00287055 0.00213565 0.00891298 0.40061241 0.58078257 0.00058531
#  0.00410054]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
ridge=Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 1e-15}
# -5.4275956094488205

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(X,y)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.174e+03, tolerance: 9.199e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.408e+03, tolerance: 9.545e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.439e+03, tolerance: 9.704e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.687e+02, tolerance: 9.588e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.211e+03, tolerance: 9.396e+00
#   model = cd_fast.enet_coordinate_descent(
# {'alpha': 0.01}
# -5.42242243603925

# %%
prediction=lasso_regressor.predict(X_test)
sns.distplot(y_test-prediction)
# Out:
# <ipython-input-24-62201203c3f4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-prediction)
# <Axes: xlabel='aqi', ylabel='Density'>

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 1.3009635924573324
# MSE: 3.167570464434715
# RMSE: 1.7797669691380147
